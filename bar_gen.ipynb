# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import pandas as pd
import barcode
from barcode.writer import ImageWriter
from PIL import Image
import os

def generate_barcodes():
    try:
        # Open file dialog to select Excel file
        file_path = filedialog.askopenfilename(filetypes=[("Excel files", "*.xlsx;*.xls")])
        if not file_path:
            return
        
        # Read Excel
        df = pd.read_excel(file_path)
        if df.shape[1] < 2:
            messagebox.showerror("Error", "Excel must have at least 2 columns (Code, Name).")
            return
        
        codes = df.iloc[:, 0].astype(str)
        names = df.iloc[:, 1].astype(str)

        # Create output folder
        output_dir = os.path.join(os.getcwd(), "barcodes_output")
        os.makedirs(output_dir, exist_ok=True)

        output_records = []

        # Generate barcodes
        for code, name in zip(codes, names):
            barcode_class = barcode.get_barcode_class('code128')
            bar = barcode_class(code, writer=ImageWriter())
            filename = os.path.join(output_dir, f"{code}.png")
            bar.save(filename)
            output_records.append([filename, name])

        # Save mapping to Excel
        output_df = pd.DataFrame(output_records, columns=["Barcode_File", "Name"])
        output_file = os.path.join(output_dir, "barcode_list.xlsx")
        output_df.to_excel(output_file, index=False)

        messagebox.showinfo("Success", f"Barcodes generated!\nSaved in: {output_dir}")

    except Exception as e:
        messagebox.showerror("Error", str(e))

# --- GUI ---
root = tk.Tk()
root.title("Excel to Barcode Converter")

frame = tk.Frame(root, padx=20, pady=20)
frame.pack()

label = tk.Label(frame, text="Convert Excel 1st column to Barcodes")
label.pack(pady=10)

btn = tk.Button(frame, text="Select Excel & Generate", command=generate_barcodes)
btn.pack(pady=10)

root.mainloop()

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
# !pip uninstall barcode pyBarcode python-barcode2 -y
# Out:
# WARNING: Skipping barcode as it is not installed.
# WARNING: Skipping pyBarcode as it is not installed.
# WARNING: Skipping python-barcode2 as it is not installed.

# %%
# !pip install python-barcode[images] pillow --upgrade
# Out:
# Requirement already satisfied: pillow in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (11.3.0)
# Requirement already satisfied: python-barcode[images] in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (0.16.1)

# %%
# !pip uninstall barcode pyBarcode python-barcode -y
# !pip install treepoem pillow
# Out:
# Found existing installation: python-barcode 0.16.1
# Uninstalling python-barcode-0.16.1:
#   Successfully uninstalled python-barcode-0.16.1
# WARNING: Skipping barcode as it is not installed.
# WARNING: Skipping pyBarcode as it is not installed.
# Collecting treepoem
#   Downloading treepoem-3.28.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: pillow in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (11.3.0)
# Downloading treepoem-3.28.0-py3-none-any.whl (373 kB)
# Installing collected packages: treepoem
# Successfully installed treepoem-3.28.0

# %%
# !pip install python-barcode==0.14.0 pillow
# Out:
# Collecting python-barcode==0.14.0
#   Downloading python_barcode-0.14.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pillow in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (11.3.0)
# Downloading python_barcode-0.14.0-py3-none-any.whl (212 kB)
# Installing collected packages: python-barcode
# Successfully installed python-barcode-0.14.0

# %%
from barcode.codex import Code128
from barcode.writer import ImageWriter

code = Code128("1234567890", writer=ImageWriter())
code.save("test_barcode")
# Out:
# 'test_barcode.png'

# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import pandas as pd
from barcode.codex import Code128
from barcode.writer import ImageWriter
from openpyxl import Workbook
from openpyxl.drawing.image import Image as XLImage
import os

def generate_barcodes():
    try:
        # Select Excel file
        file_path = filedialog.askopenfilename(filetypes=[("Excel files", "*.xlsx;*.xls")])
        if not file_path:
            return
        

        # Load Excel data
        print("loaded data")
        df = pd.read_excel(file_path)
        if df.shape[1] < 2:
            messagebox.showerror("Error", "Excel must have at least 2 columns (Code, Name).")
            return

        codes = df.iloc[:, 0].astype(str).tolist()
        names = df.iloc[:, 1].astype(str).tolist()

        # Create output folder
        output_dir = os.path.join(os.getcwd(), "barcodes_output")
        os.makedirs(output_dir, exist_ok=True)
        print("output dir created")

        # Prepare new Excel workbook
        wb = Workbook()
        ws = wb.active
        ws.title = "Barcodes"
        ws.append(["Barcode", "Name", "Code"])  # header row

        # Generate barcodes
        for row, (code, name) in enumerate(zip(codes, names), start=2):
            # Sequential filename (1.png, 2.png, 3.png, ...)
            barcode_file = os.path.join(output_dir, f"{row-1}")
            barcode_name = os.path.join(output_dir, f"{row-1}.png")
            
            

            # Generate barcode image
            Code128(code, writer=ImageWriter()).save(barcode_file)
            print("ind barcodes generated")

            # Insert into Excel
            ws.cell(row=row, column=2, value=name)  # Name
            ws.cell(row=row, column=3, value=code)  # Original code as text
            img = XLImage(barcode_name)
            print("found barcode file")
            img.width = 200
            img.height = 80
            ws.add_image(img, f"A{row}")

        # Save Excel
        print("barcodes generated")
        output_file = os.path.join(output_dir, "barcodes_with_names.xlsx")
        wb.save(output_file)
        print("excel saved")

        messagebox.showinfo("Success", f"Barcodes generated!\nSaved in:\n{output_file}")

    except Exception as e:
        messagebox.showerror("Error", str(e))

# --- GUI ---
root = tk.Tk()
root.title("Excel to Barcode Converter")

frame = tk.Frame(root, padx=20, pady=20)
frame.pack()

label = tk.Label(frame, text="Convert Excel Codes to Barcodes", font=("Arial", 12))
label.pack(pady=10)

btn = tk.Button(frame, text="Select Excel & Generate", command=generate_barcodes,
                width=30, height=2, bg="lightblue")
btn.pack(pady=15)

root.mainloop()
# Out:
# loaded data
# output dir created
# ind barcodes generated
# found barcode file
# barcodes generated
# excel saved

# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import pandas as pd
from barcode.codex import Code128
from barcode.writer import ImageWriter
from openpyxl import Workbook
from openpyxl.drawing.image import Image as XLImage
import os

def generate_barcodes():
    try:
        # Select Excel file
        file_path = filedialog.askopenfilename(filetypes=[("Excel files", "*.xlsx;*.xls")])
        if not file_path:
            return

        # Load Excel data
        df = pd.read_excel(file_path)
        if df.shape[1] < 2:
            messagebox.showerror("Error", "Excel must have at least 2 columns (Code, Name).")
            return

        codes = df.iloc[:, 0].astype(str).tolist()
        names = df.iloc[:, 1].astype(str).tolist()

        # Create a temporary output folder for images
        output_dir = os.path.join(os.getcwd(), "barcodes_temp")
        os.makedirs(output_dir, exist_ok=True)

        # Prepare new Excel workbook
        wb = Workbook()
        ws = wb.active
        ws.title = "Barcodes"
        ws.append(["Barcode", "Name", "Code"])  # header row

        # Generate barcodes
        for row, (code, name) in enumerate(zip(codes, names), start=2):
            # Sequential filename (1.png, 2.png, 3.png, ...)
            barcode_file = os.path.join(output_dir, f"{row-1}")
            barcode_name = os.path.join(output_dir, f"{row-1}.png")

            # Generate barcode image
            Code128(code, writer=ImageWriter()).save(barcode_file)

            # Insert into Excel
            ws.cell(row=row, column=2, value=name)  # Name
            ws.cell(row=row, column=3, value=code)  # Original code as text
            img = XLImage(barcode_name)
            img.width = 200
            img.height = 80
            ws.add_image(img, f"A{row}")

        # Ask user where to save Excel file
        output_file = filedialog.asksaveasfilename(
            defaultextension=".xlsx",
            filetypes=[("Excel files", "*.xlsx")],
            title="Save Excel File As"
        )
        if not output_file:
            return  # User cancelled

        wb.save(output_file)

        messagebox.showinfo("Success", f"Barcodes generated!\nSaved in:\n{output_file}")

    except Exception as e:
        messagebox.showerror("Error", str(e))

# --- GUI ---
root = tk.Tk()
root.title("Excel to Barcode Converter")

frame = tk.Frame(root, padx=20, pady=20)
frame.pack()

label = tk.Label(frame, text="Convert Excel Codes to Barcodes", font=("Arial", 12))
label.pack(pady=10)

btn = tk.Button(frame, text="Select Excel & Generate", command=generate_barcodes,
                width=30, height=2, bg="lightblue")
btn.pack(pady=15)

root.mainloop()

# %%
# !pip install reportlab
# Out:
# Collecting reportlab
#   Downloading reportlab-4.4.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from reportlab) (11.3.0)
# Requirement already satisfied: charset-normalizer in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from reportlab) (3.4.3)
# Downloading reportlab-4.4.4-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 12.6 MB/s  0:00:00
# Installing collected packages: reportlab
# Successfully installed reportlab-4.4.4

# %%
# !pip install pandas pillow python-barcode reportlab
# Out:
# Requirement already satisfied: pandas in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: pillow in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (11.3.0)
# Requirement already satisfied: python-barcode in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (0.14.0)
# Requirement already satisfied: reportlab in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (4.4.4)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset-normalizer in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from reportlab) (3.4.3)
# Requirement already satisfied: six>=1.5 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import pandas as pd
from barcode.codex import Code128
from barcode.writer import ImageWriter
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import A4
from reportlab.lib.units import mm
from reportlab.lib.utils import ImageReader
import os

def generate_barcodes_pdf():
    try:
        # Select Excel file
        file_path = filedialog.askopenfilename(filetypes=[("Excel files", "*.xlsx;*.xls")])
        if not file_path:
            return

        # Load Excel data
        df = pd.read_excel(file_path)
        if df.shape[1] < 2:
            messagebox.showerror("Error", "Excel must have at least 2 columns (Code, Name).")
            return

        codes = df.iloc[:, 0].astype(str).tolist()
        names = df.iloc[:, 5].astype(str).tolist()

        # Create temp output folder for barcode images
        output_dir = os.path.join(os.getcwd(), "barcodes_temp")
        os.makedirs(output_dir, exist_ok=True)

        # Ask user where to save PDF
        pdf_file = filedialog.asksaveasfilename(
            defaultextension=".pdf",
            filetypes=[("PDF files", "*.pdf")],
            title="Save PDF File As"
        )
        if not pdf_file:
            return  # user cancelled

        # Create PDF
        c = canvas.Canvas(pdf_file, pagesize=A4)
        width, height = A4

        y_position = height - 40 * mm  # start below top margin

        for i, (code, name) in enumerate(zip(codes, names), start=1):
            # Generate barcode PNG
            barcode_file = os.path.join(output_dir, f"{i}.png")
            Code128(code, writer=ImageWriter()).save(barcode_file)

            # Insert barcode image
            img = ImageReader(barcode_file)
            c.drawImage(img, 20 * mm, y_position, width=60 * mm, height=20 * mm, preserveAspectRatio=True, mask='auto')

            # Insert name and code text
            c.setFont("Helvetica", 10)
            c.drawString(85 * mm, y_position + 10 * mm, f"Name: {name}")
            c.drawString(85 * mm, y_position + 5 * mm, f"Code: {code}")

            # Move down for next row
            y_position -= 30 * mm
            if y_position < 40 * mm:  # new page if space runs out
                c.showPage()
                y_position = height - 40 * mm

        c.save()

        messagebox.showinfo("Success", f"PDF generated!\nSaved in:\n{pdf_file}")

    except Exception as e:
        messagebox.showerror("Error", str(e))

# --- GUI ---
root = tk.Tk()
root.title("Excel to Barcode → PDF Converter")

frame = tk.Frame(root, padx=20, pady=20)
frame.pack()

label = tk.Label(frame, text="Convert Excel Codes to Barcodes (PDF)", font=("Arial", 12))
label.pack(pady=10)

btn = tk.Button(frame, text="Select Excel & Generate PDF", command=generate_barcodes_pdf,
                width=35, height=2, bg="lightblue")
btn.pack(pady=15)

root.mainloop()

# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.2

# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import pandas as pd
from barcode.codex import Code128
from barcode.writer import ImageWriter
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import A4
from reportlab.lib.units import mm
from reportlab.lib.utils import ImageReader
import os

def generate_barcodes_pdf():
    try:
        # --- Step 1: Select Excel file ---
        file_path = filedialog.askopenfilename(filetypes=[("Excel files", "*.xlsx;*.xls")])
        if not file_path:
            return

        # --- Step 2: Load Excel data ---
        df = pd.read_excel(file_path)
        if df.shape[1] < 2:
            messagebox.showerror("Error", "Excel must have at least 2 columns (Code, Name).")
            return

        codes = df.iloc[:, 0].astype(str).tolist()
        names = df.iloc[:, 5].astype(str).tolist()

        # --- Step 3: Choose PDF output file ---
        pdf_file = filedialog.asksaveasfilename(
            defaultextension=".pdf",
            filetypes=[("PDF files", "*.pdf")],
            title="Save PDF File As"
        )
        if not pdf_file:
            return  # user cancelled

        # --- Step 4: Create temp folder for barcodes ---
        output_dir = os.path.join(os.getcwd(), "barcodes_temp")
        os.makedirs(output_dir, exist_ok=True)

        # --- Step 5: Create PDF canvas ---
        c = canvas.Canvas(pdf_file, pagesize=A4)
        width, height = A4
        y_position = height - 40 * mm  # top margin

        # --- Step 6: Generate barcodes + place in PDF ---
        for i, (code, name) in enumerate(zip(codes, names), start=1):
            # Base filename (NO extension for python-barcode)
            barcode_base = os.path.join(output_dir, f"{i}")
            barcode_name = f"{barcode_base}.png"

            # Generate barcode image (saved as {i}.png)
            Code128(code, writer=ImageWriter()).save(barcode_base)

            # Insert barcode image
            img = ImageReader(barcode_name)
            c.drawImage(img, 20 * mm, y_position, width=60 * mm, height=20 * mm,
                        preserveAspectRatio=True, mask='auto')

            # Insert name + code text beside barcode
            c.setFont("Helvetica", 10)
            c.drawString(85 * mm, y_position + 10 * mm, f"Name: {name}")
            c.drawString(85 * mm, y_position + 5 * mm, f"Code: {code}")

            # Move down
            y_position -= 30 * mm
            if y_position < 40 * mm:  # new page when space runs out
                c.showPage()
                y_position = height - 40 * mm

        # --- Step 7: Save PDF ---
        c.save()

        messagebox.showinfo("Success", f"PDF generated!\nSaved at:\n{pdf_file}")

    except Exception as e:
        messagebox.showerror("Error", str(e))


# --- GUI ---
root = tk.Tk()
root.title("Excel to Barcode → PDF Converter")

frame = tk.Frame(root, padx=20, pady=20)
frame.pack()

label = tk.Label(frame, text="Let's Convert Excel to Barcodes", font=("Arial", 12))
label.pack(pady=10)

btn = tk.Button(frame, text="Select Excel & Generate PDF", command=generate_barcodes_pdf,
                width=35, height=2, bg="lightblue")
btn.pack(pady=15)

root.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import pandas as pd
from barcode.codex import Code128
from barcode.writer import ImageWriter
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import A4
from reportlab.lib.units import mm
from reportlab.lib.utils import ImageReader
import os

def generate_barcodes_pdf():
    try:
        file_path = filedialog.askopenfilename(filetypes=[("Excel files", "*.xlsx;*.xls")])
        if not file_path:
            return

        df = pd.read_excel(file_path)
        if df.shape[1] < 2:
            messagebox.showerror("Error", "Excel must have at least 2 columns (Code, Name).")
            return

        codes = df.iloc[:, 0].astype(str).tolist()
        names = df.iloc[:, 5].astype(str).tolist()

        pdf_file = filedialog.asksaveasfilename(
            defaultextension=".pdf",
            filetypes=[("PDF files", "*.pdf")],
            title="Save PDF File As"
        )
        if not pdf_file:
            return

        output_dir = os.path.join(os.getcwd(), "barcodes_temp")
        os.makedirs(output_dir, exist_ok=True)

        c = canvas.Canvas(pdf_file, pagesize=A4)
        width, height = A4
        y_position = height - 40 * mm

        for i, (code, name) in enumerate(zip(codes, names), start=1):
            barcode_base = os.path.join(output_dir, f"{i}")
            barcode_name = f"{barcode_base}.png"
            Code128(code, writer=ImageWriter()).save(barcode_base)

            img = ImageReader(barcode_name)
            c.drawImage(img, 20 * mm, y_position, width=60 * mm, height=20 * mm,
                        preserveAspectRatio=True, mask='auto')

            c.setFont("Helvetica", 10)
            c.drawString(85 * mm, y_position + 10 * mm, f"Name: {name}")
            c.drawString(85 * mm, y_position + 5 * mm, f"Code: {code}")

            y_position -= 30 * mm
            if y_position < 40 * mm:
                c.showPage()
                y_position = height - 40 * mm

        c.save()
        messagebox.showinfo("Success", f"PDF generated!\nSaved at:\n{pdf_file}")

    except Exception as e:
        messagebox.showerror("Error", str(e))

# --- GUI ---
root = tk.Tk()
root.title("Excel to Barcode → PDF Converter")

# Fullscreen
root.state('zoomed')  # Windows full screen

# Background
root.configure(bg="#2c3e50")  # dark navy background

# Frame for content
frame = tk.Frame(root, bg="#2c3e50")
frame.place(relx=0.5, rely=0.5, anchor="center")  # center frame

# Title label
label = tk.Label(
    frame, 
    text="Let's Convert Excel to Barcodes",
    font=("Helvetica", 28, "bold"),
    fg="white",
    bg="#2c3e50"
)
label.pack(pady=40)

# Main button
btn = tk.Button(
    frame,
    text="Select Excel & Generate PDF",
    command=generate_barcodes_pdf,
    width=30,
    height=2,
    font=("Helvetica", 16, "bold"),
    bg="#3498db",     # professional blue
    fg="white",
    activebackground="#2980b9",
    activeforeground="white",
    relief="flat",
    bd=0
)
btn.pack(pady=20)

# Exit button (bottom of screen)
exit_btn = tk.Button(
    root,
    text="Exit",
    command=root.destroy,
    width=15,
    height=1,
    font=("Helvetica", 12),
    bg="#e74c3c",   # red button
    fg="white",
    activebackground="#c0392b",
    activeforeground="white",
    relief="flat",
    bd=0
)
exit_btn.pack(side="bottom", pady=30)
# --- Watermark-like label (bottom-right corner) ---
signature = tk.Label(
    root,
    text="Developed by Preetham with ❤",
    font=("Helvetica", 12),
    fg="#888888",   # white with ~30% opacity effect
    bg="#2c3e50"
)
signature.place(relx=1.0, rely=1.0, anchor="se", x=-20, y=-10)  # bottom right padding
root.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import pandas as pd
from barcode.codex import Code128
from barcode.writer import ImageWriter
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import A4
from reportlab.lib.units import mm
from reportlab.lib.utils import ImageReader
import os

def generate_barcodes_pdf():
    try:
        file_path = filedialog.askopenfilename(filetypes=[("Excel files", "*.xlsx;*.xls")])
        if not file_path:
            return

        df = pd.read_excel(file_path)
        #df = pd.read_excel(file_path, engine="openpyxl")   # for .xlsx
        #df = pd.read_excel(file_path, engine="xlrd")       # for .xls

        if df.shape[1] < 2:
            messagebox.showerror("Error", "Excel must have at least 2 columns (Code, Name).")
            return

        codes = df.iloc[:, 0].astype(str).tolist()
        names = df.iloc[:, 5].astype(str).tolist()

        pdf_file = filedialog.asksaveasfilename(
            defaultextension=".pdf",
            filetypes=[("PDF files", "*.pdf")],
            title="Save PDF File As"
        )
        if not pdf_file:
            return

        output_dir = os.path.join(os.getcwd(), "barcodes_temp")
        os.makedirs(output_dir, exist_ok=True)

        c = canvas.Canvas(pdf_file, pagesize=A4)
        width, height = A4
        y_position = height - 40 * mm

        for i, (code, name) in enumerate(zip(codes, names), start=1):
            barcode_base = os.path.join(output_dir, f"{i}")
            barcode_name = f"{barcode_base}.png"
            Code128(code, writer=ImageWriter()).save(barcode_base)

            img = ImageReader(barcode_name)
            c.drawImage(img, 20 * mm, y_position, width=60 * mm, height=20 * mm,
                        preserveAspectRatio=True, mask='auto')

            c.setFont("Helvetica", 10)
            c.drawString(85 * mm, y_position + 10 * mm, f"Name: {name}")
            c.drawString(85 * mm, y_position + 5 * mm, f"Code: {code}")

            y_position -= 30 * mm
            if y_position < 40 * mm:
                c.showPage()
                y_position = height - 40 * mm

        c.save()
        messagebox.showinfo("Success", f"PDF generated!\nSaved at:\n{pdf_file}")

    except Exception as e:
        messagebox.showerror("Error", str(e))

# --- GUI ---
root = tk.Tk()
root.title("Excel to Barcode → PDF Converter")

# Fullscreen
root.state('zoomed')  # Windows full screen

# Background
root.configure(bg="#2c3e50")  # dark navy background

# Frame for content
frame = tk.Frame(root, bg="#2c3e50")
frame.place(relx=0.5, rely=0.5, anchor="center")  # center frame

# Title label
label = tk.Label(
    frame, 
    text="Let's Convert Excel to Barcodes",
    font=("Helvetica", 28, "bold"),
    fg="white",
    bg="#2c3e50"
)
label.pack(pady=40)

# Main button
btn = tk.Button(
    frame,
    text="Select Excel & Generate PDF",
    command=generate_barcodes_pdf,
    width=30,
    height=2,
    font=("Helvetica", 16, "bold"),
    bg="#3498db",     # professional blue
    fg="white",
    activebackground="#2980b9",
    activeforeground="white",
    relief="flat",
    bd=0
)
btn.pack(pady=20)

# Exit button (bottom of screen)
exit_btn = tk.Button(
    root,
    text="Exit",
    command=root.destroy,
    width=15,
    height=1,
    font=("Helvetica", 12),
    bg="#e74c3c",   # red button
    fg="white",
    activebackground="#c0392b",
    activeforeground="white",
    relief="flat",
    bd=0
)
exit_btn.pack(side="bottom", pady=30)
# --- Watermark-like label (bottom-right corner) ---
signature = tk.Label(
    root,
    text="Developed by Preetham with ❤",
    font=("Helvetica", 12),
    fg="#888888",   # white with ~30% opacity effect
    bg="#2c3e50"
)
signature.place(relx=1.0, rely=1.0, anchor="se", x=-20, y=-10)  # bottom right padding
root.mainloop()

# %%
# !pip install pytest
# Out:
# Collecting pytest
#   Downloading pytest-8.4.2-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: colorama>=0.4 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pytest) (0.4.6)
# Collecting iniconfig>=1 (from pytest)
#   Downloading iniconfig-2.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: packaging>=20 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pytest) (25.0)
# Collecting pluggy<2,>=1.5 (from pytest)
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pytest) (2.19.2)
# Downloading pytest-8.4.2-py3-none-any.whl (365 kB)
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Downloading iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Installing collected packages: pluggy, iniconfig, pytest
#
#    ---------------------------------------- 0/3 [pluggy]
#    ------------- -------------------------- 1/3 [iniconfig]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    -------------------------- ------------- 2/3 [pytest]
#    ---------------------------------------- 3/3 [pytest]
#
# Successfully installed iniconfig-2.1.0 pluggy-1.6.0 pytest-8.4.2

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.6-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-cp313-cp313-win_amd64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.6-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------- ----------------------- 3.4/8.1 MB 17.8 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 17.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 15.5 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 16.9 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/6 [pyparsing]
#    ---------------------------------------- 0/6 [pyparsing]
#    ------ --------------------------------- 1/6 [kiwisolver]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    -------------------------- ------------- 4/6 [contourpy]
#    -------------------------- ------------- 4/6 [contourpy]
#    -------------------------- ------------- 4/6 [contourpy]
#    -------------------------- ------------- 4/6 [contourpy]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    ---------------------------------------- 6/6 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.6 pyparsing-3.2.5

# %%
# !pip install "pandas[all]"
# Out:
# Requirement already satisfied: pandas[all] in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (2025.2)
# Collecting adbc-driver-postgresql>=0.8.0 (from pandas[all])
#   Downloading adbc_driver_postgresql-1.8.0-py3-none-win_amd64.whl.metadata (4.1 kB)
# Collecting adbc-driver-sqlite>=0.8.0 (from pandas[all])
#   Downloading adbc_driver_sqlite-1.8.0-py3-none-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (4.13.5)
# Collecting bottleneck>=1.3.6 (from pandas[all])
#   Downloading bottleneck-1.6.0-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# Collecting dataframe-api-compat>=0.1.7 (from pandas[all])
#   Downloading dataframe_api_compat-0.2.7-py3-none-any.whl.metadata (1.6 kB)
# Collecting fastparquet>=2022.12.0 (from pandas[all])
#   Downloading fastparquet-2024.11.0-cp313-cp313-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: fsspec>=2022.11.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (2025.9.0)
# Collecting gcsfs>=2022.11.0 (from pandas[all])
#   Downloading gcsfs-2025.9.0-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting html5lib>=1.1 (from pandas[all])
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting hypothesis>=6.46.1 (from pandas[all])
#   Downloading hypothesis-6.140.2-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (3.1.6)
# Collecting lxml>=4.9.2 (from pandas[all])
#   Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: matplotlib>=3.6.3 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (3.10.6)
# Collecting numba>=0.56.4 (from pandas[all])
#   Downloading numba-0.62.1-cp313-cp313-win_amd64.whl.metadata (2.9 kB)
# Collecting numexpr>=2.8.4 (from pandas[all])
#   Downloading numexpr-2.13.1-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting odfpy>=1.4.1 (from pandas[all])
#   Downloading odfpy-1.4.1.tar.gz (717 kB)
#      ---------------------------------------- 0.0/717.0 kB ? eta -:--:--
#      ---------------------------------------- 717.0/717.0 kB 8.9 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: openpyxl>=3.1.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (3.1.5)
# Collecting pandas-gbq>=0.19.0 (from pandas[all])
#   Downloading pandas_gbq-0.29.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting psycopg2>=2.9.6 (from pandas[all])
#   Downloading psycopg2-2.9.10-cp313-cp313-win_amd64.whl.metadata (4.8 kB)
# Requirement already satisfied: pyarrow>=10.0.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (21.0.0)
# Collecting pymysql>=1.0.2 (from pandas[all])
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting PyQt5>=5.15.9 (from pandas[all])
#   Downloading PyQt5-5.15.11-cp38-abi3-win_amd64.whl.metadata (2.1 kB)
# Collecting pyreadstat>=1.2.0 (from pandas[all])
#   Downloading pyreadstat-1.3.1-cp313-cp313-win_amd64.whl.metadata (1.3 kB)
# Requirement already satisfied: pytest>=7.3.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (8.4.2)
# Collecting pytest-xdist>=2.2.0 (from pandas[all])
#   Downloading pytest_xdist-3.8.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting python-calamine>=0.1.7 (from pandas[all])
#   Downloading python_calamine-0.5.3-cp313-cp313-win_amd64.whl.metadata (3.2 kB)
# Collecting pyxlsb>=1.0.10 (from pandas[all])
#   Downloading pyxlsb-1.0.10-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting qtpy>=2.3.0 (from pandas[all])
#   Downloading QtPy-2.4.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (1.16.2)
# Collecting s3fs>=2022.11.0 (from pandas[all])
#   Downloading s3fs-2025.9.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: SQLAlchemy>=2.0.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (2.0.43)
# Collecting tables>=3.8.0 (from pandas[all])
#   Downloading tables-3.10.2-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
# Collecting tabulate>=0.9.0 (from pandas[all])
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting xarray>=2022.12.0 (from pandas[all])
#   Downloading xarray-2025.9.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: xlrd>=2.0.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (2.0.2)
# Collecting xlsxwriter>=3.0.5 (from pandas[all])
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: zstandard>=0.19.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas[all]) (0.24.0)
# Collecting adbc-driver-manager (from adbc-driver-postgresql>=0.8.0->pandas[all])
#   Downloading adbc_driver_manager-1.8.0-cp313-cp313-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: importlib-resources>=1.3 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from adbc-driver-postgresql>=0.8.0->pandas[all]) (6.5.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4>=4.11.2->pandas[all]) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4>=4.11.2->pandas[all]) (4.15.0)
# Collecting cramjam>=2.3 (from fastparquet>=2022.12.0->pandas[all])
#   Downloading cramjam-2.11.0-cp313-cp313-win_amd64.whl.metadata (681 bytes)
# Requirement already satisfied: packaging in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from fastparquet>=2022.12.0->pandas[all]) (25.0)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from gcsfs>=2022.11.0->pandas[all])
#   Downloading aiohttp-3.12.15-cp313-cp313-win_amd64.whl.metadata (7.9 kB)
# Requirement already satisfied: decorator>4.1.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gcsfs>=2022.11.0->pandas[all]) (5.2.1)
# Requirement already satisfied: google-auth>=1.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gcsfs>=2022.11.0->pandas[all]) (2.40.3)
# Collecting google-auth-oauthlib (from gcsfs>=2022.11.0->pandas[all])
#   Downloading google_auth_oauthlib-1.2.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting google-cloud-storage (from gcsfs>=2022.11.0->pandas[all])
#   Downloading google_cloud_storage-3.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gcsfs>=2022.11.0->pandas[all]) (2.32.5)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[all])
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[all])
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[all]) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[all])
#   Downloading frozenlist-1.7.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[all])
#   Downloading multidict-6.6.4-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[all])
#   Downloading propcache-0.3.2-cp313-cp313-win_amd64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[all])
#   Downloading yarl-1.20.1-cp313-cp313-win_amd64.whl.metadata (76 kB)
# Requirement already satisfied: idna>=2.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[all]) (3.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.2->gcsfs>=2022.11.0->pandas[all]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.2->gcsfs>=2022.11.0->pandas[all]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.2->gcsfs>=2022.11.0->pandas[all]) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.2->gcsfs>=2022.11.0->pandas[all]) (0.6.1)
# Requirement already satisfied: six>=1.9 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from html5lib>=1.1->pandas[all]) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from html5lib>=1.1->pandas[all]) (0.5.1)
# Collecting sortedcontainers<3.0.0,>=2.1.0 (from hypothesis>=6.46.1->pandas[all])
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from jinja2>=3.1.2->pandas[all]) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.3->pandas[all]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.3->pandas[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.3->pandas[all]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.3->pandas[all]) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.3->pandas[all]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.3->pandas[all]) (3.2.5)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba>=0.56.4->pandas[all])
#   Downloading llvmlite-0.45.1-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: defusedxml in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from odfpy>=1.4.1->pandas[all]) (0.7.1)
# Requirement already satisfied: et-xmlfile in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from openpyxl>=3.1.0->pandas[all]) (2.0.0)
# Requirement already satisfied: setuptools in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas-gbq>=0.19.0->pandas[all]) (80.9.0)
# Collecting db-dtypes<2.0.0,>=1.0.4 (from pandas-gbq>=0.19.0->pandas[all])
#   Downloading db_dtypes-1.4.3-py3-none-any.whl.metadata (3.0 kB)
# Collecting pydata-google-auth>=1.5.0 (from pandas-gbq>=0.19.0->pandas[all])
#   Downloading pydata_google_auth-1.9.1-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting google-api-core<3.0.0,>=2.10.2 (from pandas-gbq>=0.19.0->pandas[all])
#   Downloading google_api_core-2.25.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-cloud-bigquery<4.0.0,>=3.4.2 (from pandas-gbq>=0.19.0->pandas[all])
#   Downloading google_cloud_bigquery-3.38.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from google-api-core<3.0.0,>=2.10.2->pandas-gbq>=0.19.0->pandas[all]) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from google-api-core<3.0.0,>=2.10.2->pandas-gbq>=0.19.0->pandas[all]) (6.32.0)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core<3.0.0,>=2.10.2->pandas-gbq>=0.19.0->pandas[all])
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-cloud-core<3.0.0,>=2.4.1 (from google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq>=0.19.0->pandas[all])
#   Downloading google_cloud_core-2.4.3-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media<3.0.0,>=2.0.0 (from google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq>=0.19.0->pandas[all])
#   Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq>=0.19.0->pandas[all]) (1.74.0)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq>=0.19.0->pandas[all])
#   Downloading grpcio_status-1.75.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq>=0.19.0->pandas[all])
#   Downloading google_crc32c-1.7.1-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq>=0.19.0->pandas[all])
#   Downloading grpcio-1.75.1-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from requests->gcsfs>=2022.11.0->pandas[all]) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from requests->gcsfs>=2022.11.0->pandas[all]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from requests->gcsfs>=2022.11.0->pandas[all]) (2025.8.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from google-auth-oauthlib->gcsfs>=2022.11.0->pandas[all]) (2.0.0)
# Collecting PyQt5-sip<13,>=12.15 (from PyQt5>=5.15.9->pandas[all])
#   Downloading PyQt5_sip-12.17.0-cp313-cp313-win_amd64.whl.metadata (492 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from PyQt5>=5.15.9->pandas[all])
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (552 bytes)
# Requirement already satisfied: narwhals>=2.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pyreadstat>=1.2.0->pandas[all]) (2.4.0)
# Requirement already satisfied: colorama>=0.4 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pytest>=7.3.2->pandas[all]) (0.4.6)
# Requirement already satisfied: iniconfig>=1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pytest>=7.3.2->pandas[all]) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pytest>=7.3.2->pandas[all]) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pytest>=7.3.2->pandas[all]) (2.19.2)
# Collecting execnet>=2.1 (from pytest-xdist>=2.2.0->pandas[all])
#   Downloading execnet-2.1.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2022.11.0->pandas[all]) (3.3.1)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs>=2022.11.0->pandas[all])
#   Downloading aiobotocore-2.24.2-py3-none-any.whl.metadata (25 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11.0->pandas[all])
#   Downloading aioitertools-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting botocore<1.40.19,>=1.40.15 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11.0->pandas[all])
#   Downloading botocore-1.40.18-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11.0->pandas[all])
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11.0->pandas[all]) (1.17.3)
# Requirement already satisfied: greenlet>=1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from SQLAlchemy>=2.0.0->pandas[all]) (3.2.4)
# Collecting py-cpuinfo (from tables>=3.8.0->pandas[all])
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting blosc2>=2.3.0 (from tables>=3.8.0->pandas[all])
#   Downloading blosc2-3.9.1-cp313-cp313-win_amd64.whl.metadata (7.1 kB)
# Collecting ndindex (from blosc2>=2.3.0->tables>=3.8.0->pandas[all])
#   Downloading ndindex-1.10.0-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Collecting msgpack (from blosc2>=2.3.0->tables>=3.8.0->pandas[all])
#   Downloading msgpack-1.1.1-cp313-cp313-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: platformdirs in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from blosc2>=2.3.0->tables>=3.8.0->pandas[all]) (4.4.0)
# Downloading adbc_driver_postgresql-1.8.0-py3-none-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ---------------------------------------- 3.0/3.0 MB 14.8 MB/s  0:00:00
# Downloading adbc_driver_sqlite-1.8.0-py3-none-win_amd64.whl (955 kB)
#    ---------------------------------------- 0.0/955.9 kB ? eta -:--:--
#    ---------------------------------------- 955.9/955.9 kB 14.9 MB/s  0:00:00
# Downloading bottleneck-1.6.0-cp313-cp313-win_amd64.whl (113 kB)
# Downloading dataframe_api_compat-0.2.7-py3-none-any.whl (43 kB)
# Downloading fastparquet-2024.11.0-cp313-cp313-win_amd64.whl (673 kB)
#    ---------------------------------------- 0.0/673.3 kB ? eta -:--:--
#    ---------------------------------------- 673.3/673.3 kB 12.1 MB/s  0:00:00
# Downloading cramjam-2.11.0-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 15.5 MB/s  0:00:00
# Downloading gcsfs-2025.9.0-py2.py3-none-any.whl (36 kB)
# Downloading aiohttp-3.12.15-cp313-cp313-win_amd64.whl (449 kB)
# Downloading multidict-6.6.4-cp313-cp313-win_amd64.whl (45 kB)
# Downloading yarl-1.20.1-cp313-cp313-win_amd64.whl (86 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.7.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading hypothesis-6.140.2-py3-none-any.whl (534 kB)
#    ---------------------------------------- 0.0/534.4 kB ? eta -:--:--
#    ---------------------------------------- 534.4/534.4 kB 17.6 MB/s  0:00:00
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------------------------------ --- 3.7/4.0 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 16.8 MB/s  0:00:00
# Downloading numba-0.62.1-cp313-cp313-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 16.5 MB/s  0:00:00
# Downloading llvmlite-0.45.1-cp313-cp313-win_amd64.whl (38.1 MB)
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    --- ------------------------------------ 3.7/38.1 MB 18.7 MB/s eta 0:00:02
#    ------- -------------------------------- 7.6/38.1 MB 18.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 11.3/38.1 MB 18.4 MB/s eta 0:00:02
#    --------------- ------------------------ 15.2/38.1 MB 18.5 MB/s eta 0:00:02
#    -------------------- ------------------- 19.1/38.1 MB 18.6 MB/s eta 0:00:02
#    ------------------------ --------------- 23.1/38.1 MB 18.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 26.7/38.1 MB 18.4 MB/s eta 0:00:01
#    -------------------------------- ------- 30.7/38.1 MB 18.4 MB/s eta 0:00:01
#    ------------------------------------ --- 34.3/38.1 MB 18.3 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.1 MB 18.3 MB/s eta 0:00:01
#    ---------------------------------------- 38.1/38.1 MB 17.3 MB/s  0:00:02
# Downloading numexpr-2.13.1-cp313-cp313-win_amd64.whl (159 kB)
# Downloading pandas_gbq-0.29.2-py3-none-any.whl (40 kB)
# Downloading db_dtypes-1.4.3-py3-none-any.whl (18 kB)
# Downloading google_api_core-2.25.1-py3-none-any.whl (160 kB)
# Downloading google_cloud_bigquery-3.38.0-py3-none-any.whl (259 kB)
# Downloading google_cloud_core-2.4.3-py2.py3-none-any.whl (29 kB)
# Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
# Downloading google_crc32c-1.7.1-cp313-cp313-win_amd64.whl (33 kB)
# Downloading grpcio_status-1.75.1-py3-none-any.whl (14 kB)
# Downloading grpcio-1.75.1-cp313-cp313-win_amd64.whl (4.6 MB)
#    ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#    --------------------------------- ------ 3.9/4.6 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.6/4.6 MB 16.8 MB/s  0:00:00
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading google_auth_oauthlib-1.2.2-py3-none-any.whl (19 kB)
# Downloading propcache-0.3.2-cp313-cp313-win_amd64.whl (40 kB)
# Downloading psycopg2-2.9.10-cp313-cp313-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 15.1 MB/s  0:00:00
# Downloading pydata_google_auth-1.9.1-py2.py3-none-any.whl (15 kB)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
# Downloading PyQt5-5.15.11-cp38-abi3-win_amd64.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    --------------------- ------------------ 3.7/6.9 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.9 MB 18.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 16.2 MB/s  0:00:00
# Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#    ---------------------------------------- 0.0/50.1 MB ? eta -:--:--
#    -- ------------------------------------- 3.7/50.1 MB 18.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 7.3/50.1 MB 18.1 MB/s eta 0:00:03
#    -------- ------------------------------- 10.7/50.1 MB 17.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 13.4/50.1 MB 16.4 MB/s eta 0:00:03
#    ------------- -------------------------- 17.0/50.1 MB 16.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 20.7/50.1 MB 16.9 MB/s eta 0:00:02
#    ------------------- -------------------- 24.6/50.1 MB 17.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 28.6/50.1 MB 17.3 MB/s eta 0:00:02
#    ------------------------- -------------- 32.2/50.1 MB 17.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 36.2/50.1 MB 17.5 MB/s eta 0:00:01
#    -------------------------------- ------- 40.1/50.1 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 43.8/50.1 MB 17.6 MB/s eta 0:00:01
#    ------------------------------------- -- 47.4/50.1 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------  50.1/50.1 MB 17.8 MB/s eta 0:00:01
#    ---------------------------------------- 50.1/50.1 MB 16.7 MB/s  0:00:03
# Downloading PyQt5_sip-12.17.0-cp313-cp313-win_amd64.whl (58 kB)
# Downloading pyreadstat-1.3.1-cp313-cp313-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 16.8 MB/s  0:00:00
# Downloading pytest_xdist-3.8.0-py3-none-any.whl (46 kB)
# Downloading execnet-2.1.1-py3-none-any.whl (40 kB)
# Downloading python_calamine-0.5.3-cp313-cp313-win_amd64.whl (712 kB)
#    ---------------------------------------- 0.0/712.8 kB ? eta -:--:--
#    ---------------------------------------- 712.8/712.8 kB 14.2 MB/s  0:00:00
# Downloading pyxlsb-1.0.10-py2.py3-none-any.whl (23 kB)
# Downloading QtPy-2.4.3-py3-none-any.whl (95 kB)
# Downloading s3fs-2025.9.0-py3-none-any.whl (30 kB)
# Downloading aiobotocore-2.24.2-py3-none-any.whl (85 kB)
# Downloading aioitertools-0.12.0-py3-none-any.whl (24 kB)
# Downloading botocore-1.40.18-py3-none-any.whl (14.0 MB)
#    ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#    ---------- ----------------------------- 3.7/14.0 MB 18.8 MB/s eta 0:00:01
#    -------------------- ------------------- 7.3/14.0 MB 18.2 MB/s eta 0:00:01
#    ------------------------------- -------- 11.0/14.0 MB 18.3 MB/s eta 0:00:01
#    ---------------------------------------- 14.0/14.0 MB 17.0 MB/s  0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading tables-3.10.2-cp313-cp313-win_amd64.whl (6.4 MB)
#    ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#    ---------------------- ----------------- 3.7/6.4 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.4/6.4 MB 16.9 MB/s  0:00:00
# Downloading blosc2-3.9.1-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 16.3 MB/s  0:00:00
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading xarray-2025.9.1-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 15.1 MB/s  0:00:00
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
# Downloading adbc_driver_manager-1.8.0-cp313-cp313-win_amd64.whl (702 kB)
#    ---------------------------------------- 0.0/702.2 kB ? eta -:--:--
#    ---------------------------------------- 702.2/702.2 kB 15.3 MB/s  0:00:00
# Downloading google_cloud_storage-3.4.0-py3-none-any.whl (278 kB)
# Downloading msgpack-1.1.1-cp313-cp313-win_amd64.whl (72 kB)
# Downloading ndindex-1.10.0-cp313-cp313-win_amd64.whl (156 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: odfpy
#   Building wheel for odfpy (pyproject.toml): started
#   Building wheel for odfpy (pyproject.toml): finished with status 'done'
#   Created wheel for odfpy: filename=odfpy-1.4.1-py2.py3-none-any.whl size=137565 sha256=85959fcd404fd330b08c75e0c5748ba959538148d4c606af6e0a4bc88cc7b77b
#   Stored in directory: c:\users\prath\appdata\local\pip\cache\wheels\8e\cd\9f\979443982946991080916064e4c049b91941be1800825ff74b
# Successfully built odfpy
# Installing collected packages: sortedcontainers, pyxlsb, PyQt5-Qt5, py-cpuinfo, xlsxwriter, tabulate, qtpy, python-calamine, pyreadstat, PyQt5-sip, pymysql, psycopg2, proto-plus, propcache, odfpy, numexpr, ndindex, multidict, msgpack, lxml, llvmlite, jmespath, hypothesis, html5lib, grpcio, google-crc32c, frozenlist, execnet, dataframe-api-compat, cramjam, bottleneck, aioitertools, aiohappyeyeballs, adbc-driver-manager, yarl, pytest-xdist, PyQt5, numba, grpcio-status, google-resumable-media, botocore, blosc2, aiosignal, adbc-driver-sqlite, adbc-driver-postgresql, xarray, tables, google-auth-oauthlib, google-api-core, fastparquet, db-dtypes, aiohttp, pydata-google-auth, google-cloud-core, aiobotocore, s3fs, google-cloud-storage, google-cloud-bigquery, pandas-gbq, gcsfs
#
#    ----------------------------------------  0/60 [sortedcontainers]
#     ---------------------------------------  1/60 [pyxlsb]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    - --------------------------------------  2/60 [PyQt5-Qt5]
#    -- -------------------------------------  4/60 [xlsxwriter]
#    -- -------------------------------------  4/60 [xlsxwriter]
#    -- -------------------------------------  4/60 [xlsxwriter]
#    -- -------------------------------------  4/60 [xlsxwriter]
#    -- -------------------------------------  4/60 [xlsxwriter]
#    -- -------------------------------------  4/60 [xlsxwriter]
#    -- -------------------------------------  4/60 [xlsxwriter]
#    --- ------------------------------------  5/60 [tabulate]
#    --- ------------------------------------  5/60 [tabulate]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  6/60 [qtpy]
#    ---- -----------------------------------  7/60 [python-calamine]
#    ----- ----------------------------------  8/60 [pyreadstat]
#    ------ --------------------------------- 10/60 [pymysql]
#    ------ --------------------------------- 10/60 [pymysql]
#    ------ --------------------------------- 10/60 [pymysql]
#    ------- -------------------------------- 11/60 [psycopg2]
#    ------- -------------------------------- 11/60 [psycopg2]
#    ------- -------------------------------- 11/60 [psycopg2]
#    -------- ------------------------------- 12/60 [proto-plus]
#    -------- ------------------------------- 12/60 [proto-plus]
#    -------- ------------------------------- 12/60 [proto-plus]
#    -------- ------------------------------- 12/60 [proto-plus]
#    -------- ------------------------------- 13/60 [propcache]
#    --------- ------------------------------ 14/60 [odfpy]
#    --------- ------------------------------ 14/60 [odfpy]
#    --------- ------------------------------ 14/60 [odfpy]
#    --------- ------------------------------ 14/60 [odfpy]
#    --------- ------------------------------ 14/60 [odfpy]
#    --------- ------------------------------ 14/60 [odfpy]
#    ---------- ----------------------------- 15/60 [numexpr]
#    ---------- ----------------------------- 15/60 [numexpr]
#    ---------- ----------------------------- 15/60 [numexpr]
#    ---------- ----------------------------- 16/60 [ndindex]
#    ---------- ----------------------------- 16/60 [ndindex]
#    ---------- ----------------------------- 16/60 [ndindex]
#    ---------- ----------------------------- 16/60 [ndindex]
#    ---------- ----------------------------- 16/60 [ndindex]
#    ---------- ----------------------------- 16/60 [ndindex]
#    ----------- ---------------------------- 17/60 [multidict]
#    ------------ --------------------------- 18/60 [msgpack]
#    ------------ --------------------------- 19/60 [lxml]
#    ------------ --------------------------- 19/60 [lxml]
#    ------------ --------------------------- 19/60 [lxml]
#    ------------ --------------------------- 19/60 [lxml]
#    ------------ --------------------------- 19/60 [lxml]
#    ------------ --------------------------- 19/60 [lxml]
#    ------------ --------------------------- 19/60 [lxml]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    ------------- -------------------------- 20/60 [llvmlite]
#    -------------- ------------------------- 21/60 [jmespath]
#    -------------- ------------------------- 21/60 [jmespath]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    -------------- ------------------------- 22/60 [hypothesis]
#    --------------- ------------------------ 23/60 [html5lib]
#    --------------- ------------------------ 23/60 [html5lib]
#    --------------- ------------------------ 23/60 [html5lib]
#    --------------- ------------------------ 23/60 [html5lib]
#    --------------- ------------------------ 23/60 [html5lib]
#    --------------- ------------------------ 23/60 [html5lib]
#    --------------- ------------------------ 23/60 [html5lib]
#   Attempting uninstall: grpcio
#    --------------- ------------------------ 23/60 [html5lib]
#     Found existing installation: grpcio 1.74.0
#    --------------- ------------------------ 23/60 [html5lib]
#    ---------------- ----------------------- 24/60 [grpcio]
#     Uninstalling grpcio-1.74.0:
#    ---------------- ----------------------- 24/60 [grpcio]
#       Successfully uninstalled grpcio-1.74.0
#    ---------------- ----------------------- 24/60 [grpcio]
#    ---------------- ----------------------- 24/60 [grpcio]
#    ---------------- ----------------------- 24/60 [grpcio]
#    ---------------- ----------------------- 24/60 [grpcio]
#    ---------------- ----------------------- 24/60 [grpcio]
#    ---------------- ----------------------- 24/60 [grpcio]
#    ---------------- ----------------------- 24/60 [grpcio]
#    ---------------- ----------------------- 24/60 [grpcio]
#    ---------------- ----------------------- 24/60 [grpcio]
#    ---------------- ----------------------- 24/60 [grpcio]
#    ---------------- ----------------------- 24/60 [grpcio]
#    ---------------- ----------------------- 24/60 [grpcio]
#    ---------------- ----------------------- 24/60 [grpcio]
#    ---------------- ----------------------- 25/60 [google-crc32c]
#    ------------------ --------------------- 27/60 [execnet]
#    ------------------ --------------------- 27/60 [execnet]
#    ------------------ --------------------- 27/60 [execnet]
#    ------------------ --------------------- 27/60 [execnet]
#    ------------------ --------------------- 28/60 [dataframe-api-compat]
#    ------------------ --------------------- 28/60 [dataframe-api-compat]
#    ------------------ --------------------- 28/60 [dataframe-api-compat]
#    ------------------ --------------------- 28/60 [dataframe-api-compat]
#    -------------------- ------------------- 30/60 [bottleneck]
#    -------------------- ------------------- 30/60 [bottleneck]
#    -------------------- ------------------- 30/60 [bottleneck]
#    -------------------- ------------------- 30/60 [bottleneck]
#    -------------------- ------------------- 30/60 [bottleneck]
#    -------------------- ------------------- 31/60 [aioitertools]
#    -------------------- ------------------- 31/60 [aioitertools]
#    -------------------- ------------------- 31/60 [aioitertools]
#    --------------------- ------------------ 32/60 [aiohappyeyeballs]
#    ---------------------- ----------------- 33/60 [adbc-driver-manager]
#    ---------------------- ----------------- 33/60 [adbc-driver-manager]
#    ---------------------- ----------------- 34/60 [yarl]
#    ---------------------- ----------------- 34/60 [yarl]
#    ----------------------- ---------------- 35/60 [pytest-xdist]
#    ----------------------- ---------------- 35/60 [pytest-xdist]
#    ----------------------- ---------------- 35/60 [pytest-xdist]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 36/60 [PyQt5]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    ------------------------ --------------- 37/60 [numba]
#    -------------------------- ------------- 39/60 [google-resumable-media]
#    -------------------------- ------------- 39/60 [google-resumable-media]
#    -------------------------- ------------- 39/60 [google-resumable-media]
#    -------------------------- ------------- 39/60 [google-resumable-media]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    -------------------------- ------------- 40/60 [botocore]
#    --------------------------- ------------ 41/60 [blosc2]
#    --------------------------- ------------ 41/60 [blosc2]
#    --------------------------- ------------ 41/60 [blosc2]
#    --------------------------- ------------ 41/60 [blosc2]
#    --------------------------- ------------ 41/60 [blosc2]
#    --------------------------- ------------ 41/60 [blosc2]
#    ---------------------------- ----------- 43/60 [adbc-driver-sqlite]
#    ----------------------------- ---------- 44/60 [adbc-driver-postgresql]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 45/60 [xarray]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------ --------- 46/60 [tables]
#    ------------------------------- -------- 47/60 [google-auth-oauthlib]
#    ------------------------------- -------- 47/60 [google-auth-oauthlib]
#    -------------------------------- ------- 48/60 [google-api-core]
#    -------------------------------- ------- 48/60 [google-api-core]
#    -------------------------------- ------- 48/60 [google-api-core]
#    -------------------------------- ------- 48/60 [google-api-core]
#    -------------------------------- ------- 48/60 [google-api-core]
#    -------------------------------- ------- 48/60 [google-api-core]
#    -------------------------------- ------- 48/60 [google-api-core]
#    -------------------------------- ------- 48/60 [google-api-core]
#    -------------------------------- ------- 48/60 [google-api-core]
#    -------------------------------- ------- 48/60 [google-api-core]
#    -------------------------------- ------- 48/60 [google-api-core]
#    -------------------------------- ------- 48/60 [google-api-core]
#    -------------------------------- ------- 49/60 [fastparquet]
#    -------------------------------- ------- 49/60 [fastparquet]
#    -------------------------------- ------- 49/60 [fastparquet]
#    --------------------------------- ------ 50/60 [db-dtypes]
#    ---------------------------------- ----- 51/60 [aiohttp]
#    ---------------------------------- ----- 51/60 [aiohttp]
#    ---------------------------------- ----- 51/60 [aiohttp]
#    ---------------------------------- ----- 51/60 [aiohttp]
#    ---------------------------------- ----- 51/60 [aiohttp]
#    ---------------------------------- ----- 51/60 [aiohttp]
#    ---------------------------------- ----- 51/60 [aiohttp]
#    ---------------------------------- ----- 51/60 [aiohttp]
#    ---------------------------------- ----- 51/60 [aiohttp]
#    ---------------------------------- ----- 51/60 [aiohttp]
#    ---------------------------------- ----- 51/60 [aiohttp]
#    ---------------------------------- ----- 51/60 [aiohttp]
#    ---------------------------------- ----- 51/60 [aiohttp]
#    ---------------------------------- ----- 52/60 [pydata-google-auth]
#    ----------------------------------- ---- 53/60 [google-cloud-core]
#    ----------------------------------- ---- 53/60 [google-cloud-core]
#    ------------------------------------ --- 54/60 [aiobotocore]
#    ------------------------------------ --- 54/60 [aiobotocore]
#    ------------------------------------ --- 54/60 [aiobotocore]
#    ------------------------------------ --- 54/60 [aiobotocore]
#    ------------------------------------ --- 54/60 [aiobotocore]
#    ------------------------------------ --- 54/60 [aiobotocore]
#    ------------------------------------ --- 55/60 [s3fs]
#    ------------------------------------ --- 55/60 [s3fs]
#    ------------------------------------- -- 56/60 [google-cloud-storage]
#    ------------------------------------- -- 56/60 [google-cloud-storage]
#    ------------------------------------- -- 56/60 [google-cloud-storage]
#    ------------------------------------- -- 56/60 [google-cloud-storage]
#    ------------------------------------- -- 56/60 [google-cloud-storage]
#    ------------------------------------- -- 56/60 [google-cloud-storage]
#    ------------------------------------- -- 56/60 [google-cloud-storage]
#    ------------------------------------- -- 56/60 [google-cloud-storage]
#    ------------------------------------- -- 56/60 [google-cloud-storage]
#    ------------------------------------- -- 56/60 [google-cloud-storage]
#    ------------------------------------- -- 56/60 [google-cloud-storage]
#    -------------------------------------- - 57/60 [google-cloud-bigquery]
#    -------------------------------------- - 57/60 [google-cloud-bigquery]
#    -------------------------------------- - 57/60 [google-cloud-bigquery]
#    -------------------------------------- - 57/60 [google-cloud-bigquery]
#    -------------------------------------- - 57/60 [google-cloud-bigquery]
#    -------------------------------------- - 57/60 [google-cloud-bigquery]
#    -------------------------------------- - 57/60 [google-cloud-bigquery]
#    -------------------------------------- - 57/60 [google-cloud-bigquery]
#    -------------------------------------- - 57/60 [google-cloud-bigquery]
#    -------------------------------------- - 57/60 [google-cloud-bigquery]
#    -------------------------------------- - 57/60 [google-cloud-bigquery]
#    -------------------------------------- - 58/60 [pandas-gbq]
#    -------------------------------------- - 58/60 [pandas-gbq]
#    -------------------------------------- - 58/60 [pandas-gbq]
#    ---------------------------------------  59/60 [gcsfs]
#    ---------------------------------------  59/60 [gcsfs]
#    ---------------------------------------- 60/60 [gcsfs]
#
# Successfully installed PyQt5-5.15.11 PyQt5-Qt5-5.15.2 PyQt5-sip-12.17.0 adbc-driver-manager-1.8.0 adbc-driver-postgresql-1.8.0 adbc-driver-sqlite-1.8.0 aiobotocore-2.24.2 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aioitertools-0.12.0 aiosignal-1.4.0 blosc2-3.9.1 botocore-1.40.18 bottleneck-1.6.0 cramjam-2.11.0 dataframe-api-compat-0.2.7 db-dtypes-1.4.3 execnet-2.1.1 fastparquet-2024.11.0 frozenlist-1.7.0 gcsfs-2025.9.0 google-api-core-2.25.1 google-auth-oauthlib-1.2.2 google-cloud-bigquery-3.38.0 google-cloud-core-2.4.3 google-cloud-storage-3.4.0 google-crc32c-1.7.1 google-resumable-media-2.7.2 grpcio-1.75.1 grpcio-status-1.75.1 html5lib-1.1 hypothesis-6.140.2 jmespath-1.0.1 llvmlite-0.45.1 lxml-6.0.2 msgpack-1.1.1 multidict-6.6.4 ndindex-1.10.0 numba-0.62.1 numexpr-2.13.1 odfpy-1.4.1 pandas-gbq-0.29.2 propcache-0.3.2 proto-plus-1.26.1 psycopg2-2.9.10 py-cpuinfo-9.0.0 pydata-google-auth-1.9.1 pymysql-1.1.2 pyreadstat-1.3.1 pytest-xdist-3.8.0 python-calamine-0.5.3 pyxlsb-1.0.10 qtpy-2.4.3 s3fs-2025.9.0 sortedcontainers-2.4.0 tables-3.10.2 tabulate-0.9.0 xarray-2025.9.1 xlsxwriter-3.2.9 yarl-1.20.1

# %%
import PIL

# %%
print(PIL.__version__)
# Out:
# 11.3.0

# %%
import tkinter as tk
from tkinter import filedialog, messagebox
import pandas as pd
from barcode.codex import Code128
from barcode.writer import ImageWriter
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import A4
from reportlab.lib.units import mm
from reportlab.lib.utils import ImageReader
import os
from PIL import ImageFont

# ---- Compatibility patch for Pillow >= 10 ----
# python-barcode still calls getsize(), so we reintroduce it
if not hasattr(ImageFont.FreeTypeFont, "getsize"):
    def _getsize(self, text, *args, **kwargs):
        bbox = self.getbbox(text, *args, **kwargs)
        return (bbox[2] - bbox[0], bbox[3] - bbox[1])
    ImageFont.FreeTypeFont.getsize = _getsize
# -----------------------------------------------

def generate_barcodes_pdf():
    try:
        file_path = filedialog.askopenfilename(filetypes=[("Excel files", "*.xlsx;*.xls")])
        if not file_path:
            return

        # Explicit engine selection = avoids PyInstaller issues
        ext = os.path.splitext(file_path)[1].lower()
        if ext == ".xlsx":
            df = pd.read_excel(file_path, engine="openpyxl")
        elif ext == ".xls":
            df = pd.read_excel(file_path, engine="xlrd")
        else:
            messagebox.showerror("Error", "Unsupported file type (use .xls or .xlsx).")
            return

        if df.shape[1] < 2:
            messagebox.showerror("Error", "Excel must have at least 2 columns (Code, Name).")
            return

        codes = df.iloc[:, 0].astype(str).tolist()
        names = df.iloc[:, 5].astype(str).tolist()  # use 2nd column (not hardcoded to 5th)

        pdf_file = filedialog.asksaveasfilename(
            defaultextension=".pdf",
            filetypes=[("PDF files", "*.pdf")],
            title="Save PDF File As"
        )
        if not pdf_file:
            return

        output_dir = os.path.join(os.getcwd(), "barcodes_temp")
        os.makedirs(output_dir, exist_ok=True)

        c = canvas.Canvas(pdf_file, pagesize=A4)
        width, height = A4
        y_position = height - 40 * mm

        for i, (code, name) in enumerate(zip(codes, names), start=1):
            barcode_base = os.path.join(output_dir, f"{i}")
            barcode_name = f"{barcode_base}.png"
            Code128(code, writer=ImageWriter()).save(barcode_base)

            img = ImageReader(barcode_name)
            c.drawImage(img, 20 * mm, y_position, width=60 * mm, height=20 * mm,
                        preserveAspectRatio=True, mask='auto')

            c.setFont("Helvetica", 10)
            c.drawString(85 * mm, y_position + 10 * mm, f"Name: {name}")
            c.drawString(85 * mm, y_position + 5 * mm, f"Code: {code}")

            y_position -= 30 * mm
            if y_position < 40 * mm:
                c.showPage()
                y_position = height - 40 * mm

        c.save()
        messagebox.showinfo("Success", f"PDF generated!\nSaved at:\n{pdf_file}")

    except Exception as e:
        messagebox.showerror("Error", str(e))

# --- GUI ---
root = tk.Tk()
root.title("Excel to Barcode → PDF Converter")

# Fullscreen
root.state('zoomed')  # Windows full screen
root.configure(bg="#2c3e50")  # dark navy background

# Frame for content
frame = tk.Frame(root, bg="#2c3e50")
frame.place(relx=0.5, rely=0.5, anchor="center")  # center frame

# Title label
label = tk.Label(
    frame, 
    text="Let's Convert Excel to Barcodes",
    font=("Helvetica", 28, "bold"),
    fg="white",
    bg="#2c3e50"
)
label.pack(pady=40)

# Main button
btn = tk.Button(
    frame,
    text="Select Excel & Generate PDF",
    command=generate_barcodes_pdf,
    width=30,
    height=2,
    font=("Helvetica", 16, "bold"),
    bg="#3498db",
    fg="white",
    activebackground="#2980b9",
    activeforeground="white",
    relief="flat",
    bd=0
)
btn.pack(pady=20)

# Exit button (bottom of screen)
exit_btn = tk.Button(
    root,
    text="Exit",
    command=root.destroy,
    width=15,
    height=1,
    font=("Helvetica", 12),
    bg="#e74c3c",
    fg="white",
    activebackground="#c0392b",
    activeforeground="white",
    relief="flat",
    bd=0
)
exit_btn.pack(side="bottom", pady=30)

# Watermark
signature = tk.Label(
    root,
    text="Developed by Preetham with ❤",
    font=("Helvetica", 12),
    fg="#888888",
    bg="#2c3e50"
)
signature.place(relx=1.0, rely=1.0, anchor="se", x=-20, y=-10)

root.mainloop()
